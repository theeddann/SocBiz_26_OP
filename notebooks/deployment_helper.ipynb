# %%
import pandas as pd

# %%
pricing = pd.read_csv(
    "../processed/final_dynamic_pricing_output.csv"
)

monitoring = pd.read_csv(
    "../processed/monitoring_output_final.csv"
)

results = pd.read_csv(
    "../processed/monitoring_results.csv"
)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\900815646.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pricing = pd.read_csv(
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\900815646.py:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   monitoring = pd.read_csv(

# %%
import pandas as pd

pricing = pd.read_csv(
    "../processed/final_dynamic_pricing_output.csv"
)

print(pricing.shape)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\3961177306.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pricing = pd.read_csv(
# (2149071, 36)

# %%
import pandas as pd

pricing = pd.read_csv(
    "../processed/final_dynamic_pricing_output.csv"
)

monitoring = pd.read_csv(
    "../processed/monitoring_output_final.csv"
)

print(pricing.shape)
print(monitoring.shape)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\543549459.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pricing = pd.read_csv(
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\543549459.py:7: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   monitoring = pd.read_csv(
# (2149071, 36)
# (2149071, 9)

# %%
import pandas as pd

pricing = pd.read_csv(
    "../processed/final_dynamic_pricing_output.csv"
)

monitoring = pd.read_csv(
    "../processed/monitoring_output_final.csv"
)

results = pd.read_csv(
    "../processed/monitoring_results.csv"
)

print("Loaded")
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\324210967.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pricing = pd.read_csv(
# C:\Users\shubh\AppData\Local\Temp\ipykernel_25556\324210967.py:7: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   monitoring = pd.read_csv(
# Loaded

# %%
pricing_demo = pricing.sample(
    n=5000,
    random_state=42
)

pricing_demo.to_csv(
    "../processed/dynamic_pricing_demo.csv",
    index=False
)

print(pricing_demo.shape)
# Out:
# (5000, 36)

# %%
monitoring_demo = monitoring.sample(
    n=5000,
    random_state=42
)

monitoring_demo.to_csv(
    "../processed/monitoring_output_demo.csv",
    index=False
)

print(monitoring_demo.shape)
# Out:
# (5000, 9)

# %%
import os

print(os.listdir("../processed"))
# Out:
# ['demand_prediction_model.pkl', 'dynamic_pricing_demo.csv', 'dynamic_pricing_output.csv', 'final_dynamic_pricing_output.csv', 'monitoring_output_demo.csv', 'monitoring_output_final.csv', 'monitoring_results.csv', 'urban_demand_model.pkl']
